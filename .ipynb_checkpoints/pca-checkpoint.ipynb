# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_breast_cancer
cancer=load_breast_cancer()
cancer_data=cancer.data
cancer_data.shape
# Out:
# (569, 30)

# %%
# construct a dataframe using pandas
df=pd.DataFrame(cancer['data'],columns=cancer['feature_names'])
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
scaling=StandardScaler()
 
scaling.fit(df)
Scaled_data=scaling.transform(df)
 
principal=PCA(n_components=3)
principal.fit(Scaled_data)
x=principal.transform(Scaled_data)
 
print(x.shape)
# Out:
# (569, 3)

# %%
# Check the values of eigen vectors
# prodeced by principal components
principal.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611302,
#          0.15189161,  0.06016537, -0.0347675 ,  0.19034877,  0.36657548,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443046,
#          0.23271589,  0.19720728,  0.13032156,  0.183848  ,  0.28009202,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796412, -0.00825723,  0.14188335,  0.27533947],
#        [-0.00853123,  0.0645499 , -0.00931421,  0.02869953, -0.10429185,
#         -0.07409158,  0.0027338 , -0.02556357, -0.04023994, -0.02257414,
#          0.26848139,  0.37463366,  0.26664536,  0.21600654,  0.30883895,
#          0.15477977,  0.17646376,  0.22465756,  0.28858429,  0.21150379,
#         -0.04750698, -0.04229781, -0.0485465 , -0.01190232, -0.25979759,
#         -0.23607561, -0.17305735, -0.1703441 , -0.27131263, -0.23279133]])

# %%
plt.figure(figsize=(5,5))
plt.scatter(x[:,0],x[:,1],c=cancer['target'],cmap='coolwarm')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Out:
# Text(0, 0.5, 'Principal Component 2')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(6,6))
axis = fig.add_subplot(111, projection='3d')

axis.scatter(x[:,0],x[:,1],x[:,2], c=cancer['target'],cmap='coolwarm')
axis.set_xlabel("PC1", fontsize=10)
axis.set_ylabel("PC2", fontsize=10)
axis.set_zlabel("PC3", fontsize=10)
# Out:
# Text(0.5, 0, 'PC3')

# %%
# check how much variance is explained by each principal component
print(principal.explained_variance_ratio_)
# Out:
# [0.44272026 0.18971182 0.09393163]
